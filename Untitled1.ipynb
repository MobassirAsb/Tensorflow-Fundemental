# %% [markdown]
# ## Creating a data to fit

# %%
#Import Dependancies
import numpy as np
import pandas as pd
import tensorflow as tf
import matplotlib.pyplot as plt

# %%
#Creating a feature
x = np.array([3.0, 5.0, 7.0 , 4.0 , 6.0, 9.0, 2.0])

# Creating a Lebel
y = np.array([13, 15 , 17 , 14 , 16 , 19,  12])

# %%
x
# Out:
# array([3., 5., 7., 4., 6., 9., 2.])

# %%
y
# Out:
# array([13, 15, 17, 14, 16, 19, 12])

# %%
plt.scatter(x,y)

# %%
x+10
# Out:
# array([13., 15., 17., 14., 16., 19., 12.])

# %%
y == x+10
# Out:
# array([ True,  True,  True,  True,  True,  True,  True])

# %%
 house_info = tf.constant(['Bedroom' , 'Barthroom' , 'Garage'])
 house_price = tf.constant([97000700])

# %%
house_info , house_price
# Out:
# (<tf.Tensor: shape=(3,), dtype=string, numpy=array([b'Bedroom', b'Barthroom', b'Garage'], dtype=object)>,
#  <tf.Tensor: shape=(1,), dtype=int32, numpy=array([97000700], dtype=int32)>)

# %%
input_shape = x.shape
output_shape = y.shape
input_shape , output_shape
# Out:
# ((7,), (7,))

# %%
x[0].shape , y[0].shape
# Out:
# ((), ())

# %%
x[0], y[0]
# Out:
# (3.0, 13)

# %%
x[3], y[3]
# Out:
# (4.0, 14)

# %%
x[0].ndim
# Out:
# 0

# %%
# Creating Tensor and convrting this numpy array
x = (tf.constant(x, dtype = tf.float32))
y = (tf.constant(y, dtype = tf.float32))

# %%
# Create a  Model
model = tf.keras.Sequential([
    tf.keras.layers.Dense(1)
])

model.compile(loss = tf.keras.losses.mae,  # mae mean men absoulate Eroor
              optimizer = tf.keras.optimizers.SGD(), # Sochestic Gradient Descent
              metrics = ['mae']
              )
model.fit(tf.expand_dims(x , axis= 1), y, epochs = 5)
# Out:
# Epoch 1/5
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 640ms/step - loss: 23.4276 - mae: 23.4276
# Epoch 2/5
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 175ms/step - loss: 23.1531 - mae: 23.1531
# Epoch 3/5
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step - loss: 22.8786 - mae: 22.8786
# Epoch 4/5
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step - loss: 22.6041 - mae: 22.6041
# Epoch 5/5
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step - loss: 22.3297 - mae: 22.3297

# %%
x ,y
# Out:
# (<tf.Tensor: shape=(7,), dtype=float32, numpy=array([3., 5., 7., 4., 6., 9., 2.], dtype=float32)>,
#  <tf.Tensor: shape=(7,), dtype=float32, numpy=array([13., 15., 17., 14., 16., 19., 12.], dtype=float32)>)

# %%
model.predict(tf.constant([8.0]))
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step
# array([[-10.780261]], dtype=float32)

# %%
# Rebuid our Model
tf.random.set_seed(41)
model = tf.keras.Sequential([
    tf.keras.layers.Dense(1)
])
model.compile(loss = tf.keras.losses.mae,
              optimizer = tf.keras.optimizers.SGD(),
              metrics =['mae']
              )
model.fit(tf.expand_dims(x, axis = 1),y,epochs = 100)
# Out:
# Epoch 1/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 471ms/step - loss: 17.2300 - mae: 17.2300
# Epoch 2/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - loss: 16.9555 - mae: 16.9555
# Epoch 3/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 16.6811 - mae: 16.6811
# Epoch 4/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - loss: 16.4066 - mae: 16.4066
# Epoch 5/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 16.1321 - mae: 16.1321
# Epoch 6/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - loss: 15.8576 - mae: 15.8576
# Epoch 7/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 15.5831 - mae: 15.5831
# Epoch 8/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 15.3086 - mae: 15.3086
# Epoch 9/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 15.0341 - mae: 15.0341
# Epoch 10/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 14.7596 - mae: 14.7596
# Epoch 11/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 14.4851 - mae: 14.4851
# Epoch 12/100
# ...

# %%
 x , y
# Out:
# (<tf.Tensor: shape=(7,), dtype=float32, numpy=array([3., 5., 7., 4., 6., 9., 2.], dtype=float32)>,
#  <tf.Tensor: shape=(7,), dtype=float32, numpy=array([13., 15., 17., 14., 16., 19., 12.], dtype=float32)>)

# %%
y_pred = model.predict(tf.constant([8.0]))
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step

# %%
print(y_pred)
# Out:
# [[21.11611]]

# %%
#Improve the model
#Improve the model
tf.random.set_seed(42)
model = tf.keras.Sequential([
     tf.keras.layers.Dense(50, activation = None),
     tf.keras.layers.Dense(1)

])

model.compile(loss = tf.keras.losses.mae,
              optimizer = tf.keras.optimizers.Adam(learning_rate = 0.00+1),
              metrics = ['mae']
              )
model.fit(tf.expand_dims(x, axis = 1), y , epochs = 100)
# Out:
# Epoch 1/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step - loss: 16.8660 - mae: 16.8660
# Epoch 2/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 73ms/step - loss: 26.6453 - mae: 26.6453
# Epoch 3/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 493.1157 - mae: 493.1157
# Epoch 4/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - loss: 360.9597 - mae: 360.9597
# Epoch 5/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - loss: 140.2528 - mae: 140.2528
# Epoch 6/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step - loss: 8.3042 - mae: 8.3042
# Epoch 7/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 17.6179 - mae: 17.6179
# Epoch 8/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - loss: 63.7624 - mae: 63.7624
# Epoch 9/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 134.8972 - mae: 134.8972
# Epoch 10/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - loss: 144.3954 - mae: 144.3954
# Epoch 11/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - loss: 81.3503 - mae: 81.3503
# Epoch 12/100
# ...

# %%
x,y
# Out:
# (<tf.Tensor: shape=(7,), dtype=float32, numpy=array([3., 5., 7., 4., 6., 9., 2.], dtype=float32)>,
#  <tf.Tensor: shape=(7,), dtype=float32, numpy=array([13., 15., 17., 14., 16., 19., 12.], dtype=float32)>)

# %%
model.predict(tf.constant([8]))
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 95ms/step
# array([[18.945189]], dtype=float32)
